# %%
#from datetime import datetime
import pickle
import datetime
from datetime import timedelta
from datetime import datetime as dt
import math
import sys


class Pet:
    def __init__(self, name, dob, weight, owner):
        self.__name = name
        self.__dob = dob
        self.__weight = weight
        self.__owner = owner

    def get_name(self):
        return self.__name

    def get_dob(self):
        return self.__dob

    def get_weight(self):
        return self.__weight

    def get_owner(self):
        return self.__owner

    def set_name(self, n):
        self.__name = n

    def set_dob(self, d):
        self.__dob = d

    def set_weight(self, w):
        self.__weight = w

    def set_owner(self, o):
        self.__owner = o

    def calage(self):
        age = (dt.now().date() - self.get_dob()).days
        age = int(age)
        return age

    def __str__(self):
        result = 'Pet Name: {0}; Pet DOB: {1}; Birth Weight {2}\n'.format(self.__name, self.__dob, self.__weight )
        result += 'Owner Name: {0}; Owner Address: {1}\n'.format(self.__owner.get_ownername(),self.__owner.get_address())
        return result


class Mammal(Pet):
    def __init__(self, name, dob, weight, owner, size, hasclaws):
        super().__init__(name, dob, weight, owner)
        self.__size = size
        self.__hasclaws = hasclaws

    def get_size(self):
        return self.__size

    def get_hasclaws(self):
        return self.__hasclaws

    def set_size(self, s):
        self.__size = s

    def set_hasclaws(self, h):
        self.__hasclaws = h

    def calweight(self):
        age = self.calage()
        if age < 301:
            self.set_weight(self.get_weight() * (pow((1 + 8 / 100), age//50)))
            return self.get_weight()
        elif age > 300:
            self.set_weight(self.get_weight()*(pow((1 + 8 / 100), 6)))
            return self.get_weight()

    def __str__(self):
        print("Details of this Mammal pet are:")
        result = Pet.__str__(self)
        result += 'Litter Size: {0}; Has Claws? {1}\n'.format(self.__size, 'Yes' if self.__hasclaws == True else 'No')
        return result


class Fish(Pet):
    def __init__(self, name, dob, weight, owner, condition, length):
        super().__init__(name, dob, weight, owner)
        self.__condition = condition
        self.__length = length

    def get_condition(self):
        return self.__size

    def get_length(self):
        return self.__length

    def set_condition(self, c):
        self.__condition = c

    def set_length(self, le):
        self.__length = le

    def calweight(self):
        age = self.calage()
        if age < 361:
            self.set_weight(self.get_weight() * (pow((1 + 4 / 100), age // 90)))
            return self.get_weight()
        elif age > 360:
            self.set_weight(self.get_weight() * (pow((1 + 4 / 100), 4)))
            return self.get_weight()

    def __str__(self):
        print("Details of this Fish pet are:")
        result = Pet.__str__(self)
        result += 'Scale Condition : {0}; Length: {1}\n'.format(self.__condition, self.__length)
        return result


class Amphibians(Pet):
    def __init__(self, name, dob, weight, owner, isVenomous):
        super().__init__(name, dob, weight, owner)
        self.__isVenomous = isVenomous

    def get_isVenomous(self):
        return self.__isVenomous

    def set_isVenomous(self, i):
        self.__isVenomous = i

    def calweight(self):
        age = self.calage()  # age = (dt.now().date() - self.get_dob()).days
        if age < 361:
            self.set_weight(self.get_weight() * (pow((1 + 5 / 100), age // 120)))
            return self.get_weight()
        elif age > 360 and age <601:
            self.set_weight(self.get_weight() *(pow((1 + 5 / 100), 3)) * (pow((1 + 3 / 100), (age - 360) // 120)))
            return self.get_weight()
        elif age > 600:

            self.set_weight(self.get_weight() * (pow((1 + 5 / 100),3) ) * (pow((1 + 3 / 100),2)))
            return self.get_weight()

    def __str__(self):
        print("Details of this Amphibian pet are:")
        result = Pet.__str__(self)
        result += 'Is Venomous? {0}\n'.format('Yes' if self.__isVenomous == True else 'No')
        return result


class Person:
    def __init__(self, ownername, address):
        self.__ownername = ownername
        self.__address = address

    def get_ownername(self):
        return self.__ownername

    def get_address(self):
        return self.__address

    def set_ownername(self, on):
        self.__ownername = on

    def set_address(self, a):
        self.__address = a


def getinfor():
    try:
        name = str(input("Enter the pet's name:"))
        dob_entry = input("Enter the pet date of birth (year, month, date):")
        Year, Month, Day = map(int, dob_entry.split(','))
        if Year < 0 or Month < 0 or Month > 12 or Day < 0 or Day > 31:
            raise Exception
        if Year < 99:
            Year = Year+2000
        dob = datetime.date(Year, Month, Day)
        weight = float(input("Enter the pet's birth weight:"))
        ownername = str(input("Enter the owner's name:"))
        address = str(input("Enter the owner's address:"))

        return name, dob, weight, ownername, address
    except ValueError:
        print('Invalid type of input')
        sys.exit()
    except Exception:
        print('Error in input!!')
        sys.exit()


def saveData(objecttype):
    with open('petdata.dat', 'ab') as fb:
        pickle.dump(objecttype, fb)
    fb.close()


def readData():
    with open('petdata.dat', 'rb') as fb:
        try:
            while (True):
                allinfor = pickle.load(fb)
                print(allinfor)
        except EOFError:
            pass
        fb.close()


def findData():
    with open('petdata.dat', 'rb') as fb:
        try:
            while (True):
                findinfor = pickle.load(fb)  #(dt.now().date() - findinfor.get_dob()).days
                row = '{0} weight {1} pounds and is {2} days old'.format(findinfor.get_name(),math.floor(findinfor.calweight()), findinfor.calage())
                print(row)
        except EOFError:
            pass
        fb.close()

def menu():
    Check = True
    while Check == True:
        print("====Menu====")
        print("1. To add a pet")
        print("2. To print current weight of all pets")
        print("3. To print all pets and owners")
        print("4. To exit the program")
        try:
            select = int(input("Your selection:"))
            if select == 1:
                type = int(input("Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):"))
                if type == 1 or type == 2 or type == 3:
                    name, dob, weight, ownername, address = getinfor()
                    owner = Person(ownername, address)
                    if type == 1:
                        size = int(input("Enter the pet litter size:"))
                        question = str(input("Does the pet claws? Answer 'yes' or 'no': "))
                        if question == "yes":
                            hasclaws = True
                        elif question == "no":
                            hasclaws = False
                        else:
                            print('Error in input!!')
                            sys.exit()

                        Mammals = Mammal(name, dob, weight, owner, size, hasclaws)
                        saveData(Mammals)
                    elif type == 2:
                        condition = str(input("Enter the pet's scale condition:"))
                        length = float(input("Enter the pet's length:"))
                        Fishs = Fish(name, dob, weight, owner, condition, length)
                        saveData(Fishs)
                    elif type == 3:
                        question = str(input("is the pet venomous? Answer 'yes' or 'no': "))
                        if question == "yes":
                            isVenomous = True
                        elif question == "no":
                            isVenomous = False
                        else:
                            print('Error in input!!')
                            sys.exit()

                        Amphibian = Amphibians(name, dob, weight, owner, isVenomous)
                        saveData(Amphibian)
                else:
                    print(type)
                    print("You entered valid values. Please enter again")
                    select = 1
            elif select == 2:
                print()
                print("Pent name and current weight of all pets")
                print("=========================================")
                findData()
            elif select == 3:
                print()
                readData()
            elif select == 4:
                print("You chose to exit the program")
                exitprogram = str(input("Are you sure (Y/N)?"))
                if exitprogram == "y" or exitprogram == "Y":
                    print("Data saved to petdate.dat")
                    print("Goodbye")
                    Check = False
                elif exitprogram == "n" or exitprogram == "N":
                    Check = True
                else:
                    print("Valid values return to menu")
                    Check = True
            else:
                print("You entered valid values. Please enter again")
        except ValueError:
            print("You entered valid values. Please enter digit number")
            Check = True


def main():
    menu()


if __name__ == "__main__":
     main()
# Out:
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):Kaazi
# You entered valid values. Please enter digit number
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):1
# Enter the pet's name:Kaazi
# Enter the pet date of birth (year, month, date):19,12,20
# Enter the pet's birth weight:100
# Enter the owner's name:Amy
# Enter the owner's address:123 Main
# Enter the pet litter size:3
# Does the pet claws? Answer 'yes' or 'no': yes
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:2
#
# Pent name and current weight of all pets
# =========================================
# Kaazi weight 158 pounds and is 345 days old
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:3
#
# Details of this Mammal pet are:
# Pet Name: Kaazi; Pet DOB: 2019-12-20; Birth Weight 100.0
# Owner Name: Amy; Owner Address: 123 Main
# Litter Size: 3; Has Claws? Yes
#
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):2
# Enter the pet's name:Goldie
# Enter the pet date of birth (year, month, date):2018,10,31
# Enter the pet's birth weight:90
# Enter the owner's name:Brett
# Enter the owner's address:345 Main
# Enter the pet's scale condition:rough
# Enter the pet's length:15
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):2
# Enter the pet's name:Lightning
# Enter the pet date of birth (year, month, date):2020,1,12
# Enter the pet's birth weight:80
# Enter the owner's name:Cathy
# Enter the owner's address:456 Main
# Enter the pet's scale condition:scaly
# Enter the pet's length:20
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):3
# Enter the pet's name:Toad
# Enter the pet date of birth (year, month, date):2019,6,1
# Enter the pet's birth weight:78
# Enter the owner's name:Dina
# Enter the owner's address:678 Main
# is the pet venomous? Answer 'yes' or 'no': no
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):1
# Enter the pet's name:Yogi
# Enter the pet date of birth (year, month, date):2020,2,2
# Enter the pet's birth weight:50
# Enter the owner's name:Eric
# Enter the owner's address:890 Main
# Enter the pet litter size:5
# Does the pet claws? Answer 'yes' or 'no': no
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):2
# Enter the pet's name:Streak
# Enter the pet date of birth (year, month, date):2020,2,2
# Enter the pet's birth weight:102
# Enter the owner's name:Farida
# Enter the owner's address:111 Pike
# Enter the pet's scale condition:scaly
# Enter the pet's length:25
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):3
# Enter the pet's name:Croak
# Enter the pet date of birth (year, month, date):2020,2,5
# Enter the pet's birth weight:92
# Enter the owner's name:Geng
# Enter the owner's address:222 Peak
# is the pet venomous? Answer 'yes' or 'no': yes
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):3
# Enter the pet's name:Hiss
# Enter the pet date of birth (year, month, date):2019,5,8
# Enter the pet's birth weight:48
# Enter the owner's name:Harish
# Enter the owner's address:333 Oak
# is the pet venomous? Answer 'yes' or 'no': yes
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:1
# Type of pet?(1-Mammals; 2-Fish; 3-Amphibian):2
# Enter the pet's name:Sliver
# Enter the pet date of birth (year, month, date):2018,7,1
# Enter the pet's birth weight:15
# Enter the owner's name:Indira
# Enter the owner's address:444 Pine
# Enter the pet's scale condition:rough
# Enter the pet's length:30
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:2
#
# Pent name and current weight of all pets
# =========================================
# Kaazi weight 158 pounds and is 345 days old
# Goldie weight 105 pounds and is 760 days old
# Lightning weight 89 pounds and is 322 days old
# Toad weight 93 pounds and is 547 days old
# Yogi weight 79 pounds and is 301 days old
# Streak weight 114 pounds and is 301 days old
# Croak weight 101 pounds and is 298 days old
# Hiss weight 57 pounds and is 571 days old
# Sliver weight 17 pounds and is 882 days old
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:3
#
# Details of this Mammal pet are:
# Pet Name: Kaazi; Pet DOB: 2019-12-20; Birth Weight 100.0
# Owner Name: Amy; Owner Address: 123 Main
# Litter Size: 3; Has Claws? Yes
#
# Details of this Fish pet are:
# Pet Name: Goldie; Pet DOB: 2018-10-31; Birth Weight 90.0
# Owner Name: Brett; Owner Address: 345 Main
# Scale Condition : rough; Length: 15.0
#
# Details of this Fish pet are:
# Pet Name: Lightning; Pet DOB: 2020-01-12; Birth Weight 80.0
# Owner Name: Cathy; Owner Address: 456 Main
# Scale Condition : scaly; Length: 20.0
#
# Details of this Amphibian pet are:
# Pet Name: Toad; Pet DOB: 2019-06-01; Birth Weight 78.0
# Owner Name: Dina; Owner Address: 678 Main
# Is Venomous? No
#
# Details of this Mammal pet are:
# Pet Name: Yogi; Pet DOB: 2020-02-02; Birth Weight 50.0
# Owner Name: Eric; Owner Address: 890 Main
# Litter Size: 5; Has Claws? No
#
# Details of this Fish pet are:
# Pet Name: Streak; Pet DOB: 2020-02-02; Birth Weight 102.0
# Owner Name: Farida; Owner Address: 111 Pike
# Scale Condition : scaly; Length: 25.0
#
# Details of this Amphibian pet are:
# Pet Name: Croak; Pet DOB: 2020-02-05; Birth Weight 92.0
# Owner Name: Geng; Owner Address: 222 Peak
# Is Venomous? Yes
#
# Details of this Amphibian pet are:
# Pet Name: Hiss; Pet DOB: 2019-05-08; Birth Weight 48.0
# Owner Name: Harish; Owner Address: 333 Oak
# Is Venomous? Yes
#
# Details of this Fish pet are:
# Pet Name: Sliver; Pet DOB: 2018-07-01; Birth Weight 15.0
# Owner Name: Indira; Owner Address: 444 Pine
# Scale Condition : rough; Length: 30.0
#
# ====Menu====
# 1. To add a pet
# 2. To print current weight of all pets
# 3. To print all pets and owners
# 4. To exit the program
# Your selection:4
# You chose to exit the program
# Are you sure (Y/N)?y
# Data save to petdate.dat
# Goodbye
